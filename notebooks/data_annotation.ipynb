# %%
import os
import json

# %% [markdown]
# If you are unsure or none of the option applies simply choose n/a
# - gender: man / woman / n/a
# - age: young / old / n/a (choose young for students and old if person is clearly >40)
# - ethnicity: Caucasian / Asian / African / n/a
# - facial expression: open mouth / smiling / closed eyes / raised brows / puffed cheeks / n/a (choose n/a for sad!)
# - emotion: happy / sad / n/a (choose n/a for all expressions that are not smiling or sad!)
# - hairstyle: hat / ponytail / straight hair / curly hair / n/a (choose hat for any kind of Kopfbedeckung --> adapt prompt @Katha)
#
# was nicht drin ist: dick / dünn, long hair / short hair

# %%
heads = []

head_data = {}
head_data['id'] = '003_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '004_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '005_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '006_000'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '007_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '008_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '009_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '010_000'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '011_000'
head_data['gender'] = 'woman'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '012_000'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '013_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '014_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '015_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '016_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '017_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '017_018'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '018_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '018_017'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '019_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '020_000'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '021_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '022_000'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '023_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '024_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '025_000'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '055_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '056_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '057_006'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '058_016'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '059_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '060_018'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '061_006'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'hat'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '062_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '064_016'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '065_018'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '067_017'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '068_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '069_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '070_014'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '071_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '072_017'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '073_014'
head_data['gender'] = 'woman'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '074_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'hat'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '075_017'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'hat'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '076_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '077_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '078_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '079_018'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '080_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '081_016'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '082_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '083_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '085_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '086_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '087_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '088_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '089_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '090_015'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '091_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '092_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '096_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '097_015'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '098_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '099_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '100_006'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '102_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '103_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '104_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '105_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '106_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '108_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '109_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '110_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '111_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '112_018'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '113_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '114_016'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '115_016'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '117_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '118_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '120_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '121_016'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '122_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '123_018'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '124_018'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '125_015'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'hat'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '126_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '127_016'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '128_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '129_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '130_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '131_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '132_016'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '133_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'hat'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '134_012'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '135_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '136_006'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '137_019'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '138_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '140_019'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '141_006'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '142_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'hat'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '143_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '144_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '145_015'
head_data['gender'] = 'woman'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '146_018'
head_data['gender'] = 'man'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '147_025'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '148_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '149_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '150_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'hat'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '151_014'
head_data['gender'] = 'n/a'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '162_004'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '163_006'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '164_016'
head_data['gender'] = 'n/a'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'hat'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '165_007'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '167_004'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '174_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '179_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '180_014'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '181_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '182_014'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '183_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '184_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '185_016'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '186_006'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '187_014'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '188_018'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '189_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '190_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '191_016'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '193_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '194_020'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '195_014'
head_data['gender'] = 'woman'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '196_014'
head_data['gender'] = 'woman'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '198_017'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '199_014'
head_data['gender'] = 'n/a'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'curly hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '200_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '201_006'
head_data['gender'] = 'n/a'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '202_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '204_016'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'n/a'
heads.append(head_data)

head_data = {}
head_data['id'] = '206_016'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '207_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '209_016'
head_data['gender'] = 'woman'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '210_014'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '211_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '212_016'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '213_016'
head_data['gender'] = 'man'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '214_014'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '215_014'
head_data['gender'] = 'woman'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '216_018'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '217_018'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '218_006'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '220_014'
head_data['gender'] = 'man'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '221_014'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '223_017'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '224_017'
head_data['gender'] = 'man'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '226_018'
head_data['gender'] = 'woman'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '227_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '228_014'
head_data['gender'] = 'woman'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '229_015'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '231_015'
head_data['gender'] = 'man'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '232_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '233_015'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '234_018'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '235_018'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '237_018'
head_data['gender'] = 'man'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '238_014'
head_data['gender'] = 'woman'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '239_018'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Asian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '240_018'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '241_015'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '242_018'
head_data['gender'] = 'man'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'raised brows'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '243_016'
head_data['gender'] = 'man'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '244_017'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'puffed cheeks'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '245_017'
head_data['gender'] = 'woman'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '246_018'
head_data['gender'] = 'n/a'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'closed eyes'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '247_007'
head_data['gender'] = 'man'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '248_017'
head_data['gender'] = 'man'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'n/a'
head_data['emotion'] = 'sad'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'yes'
heads.append(head_data)

head_data = {}
head_data['id'] = '249_014'
head_data['gender'] = 'man'
head_data['age'] = 'n/a'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '250_014'
head_data['gender'] = 'woman'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'ponytail'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '251_014'
head_data['gender'] = 'woman'
head_data['age'] = 'old'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'smiling'
head_data['emotion'] = 'happy'
head_data['hairstyle'] = 'n/a'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '252_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'n/a'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)

head_data = {}
head_data['id'] = '254_006'
head_data['gender'] = 'man'
head_data['age'] = 'young'
head_data['ethnicity'] = 'Caucasian'
head_data['facial_expression'] = 'open mouth'
head_data['emotion'] = 'n/a'
head_data['hairstyle'] = 'straight hair'
head_data['beard'] = 'no'
heads.append(head_data)
        
data = {"heads": heads}
#print(data)

# %%
# Save data as a JSON file
save_path = '/Users/katharinaschmid/Text2Head/rendering_data/head_annotations.json'
with open(save_path, "w") as json_file:
    json.dump(data, json_file)

# %% [markdown]
# Make sure that for every element in the annotation there is a corresponding mesh.
# --> every id only appears once and there is a corresponding mesh for every id

# %%
path = '/Volumes/Seagate/Data/annotated_dataset/'
# Iterate through 'id's
for entry in data["heads"]:
    current_id = entry["id"]
    ply_file_path = os.path.join(path, current_id + ".ply")
    print("Checking for ID:", current_id)

    # Check if the corresponding .ply file exists
    if os.path.exists(ply_file_path):
        continue
    else:
        print("   .ply file not found for ID:", current_id)

# %% [markdown]
# Make sure we don't have any spelling mistakes or inconsistencies

# %%
# Get the keys within the "heads" data
keys_within_heads = data["heads"][0].keys()

# Iterate through keys and print unique options
for key in keys_within_heads:
    if key == 'id':
        continue
    print(f"Options for '{key}':")
    unique_options = set(entry[key] for entry in data["heads"])
    for option in unique_options:
        print(f"   {option}")
    print()

# %%
# Identity: Gender
male_indices = [index for index, head in enumerate(data['heads']) if head['gender'] == 'man']
print('male: ', len(male_indices))
print(male_indices)
female_indices = [index for index, head in enumerate(data['heads']) if head['gender'] == 'woman']
print('female: ', len(female_indices))
print('############')

# Identity: Age
young_indices = [index for index, head in enumerate(data['heads']) if head['age'] == 'young']
print('young: ', len(young_indices))
old_indices = [index for index, head in enumerate(data['heads']) if head['age'] == 'old']
print('old: ', len(old_indices))
print('############')

# Identity: Hairstyle
hat_indices = [index for index, head in enumerate(data['heads']) if head['hairstyle'] == 'hat']
print('hat: ', len(hat_indices))
ponytail_indices = [index for index, head in enumerate(data['heads']) if head['hairstyle'] == 'ponytail']
print('ponytail: ', len(ponytail_indices))
straight_hair_indices = [index for index, head in enumerate(data['heads']) if head['hairstyle'] == 'straight hair']
print('straight hair: ', len(straight_hair_indices))
curly_hair_indices = [index for index, head in enumerate(data['heads']) if head['hairstyle'] == 'curly hair']
print('curly hair: ', len(curly_hair_indices))
print('############')

# Identity: Beard
beard_indices = [index for index, head in enumerate(data['heads']) if head['beard'] == 'yes']
print('beard: ', len(beard_indices))
print('############')

# Identity: Ethnicity
caucasian_indices = [index for index, head in enumerate(data['heads']) if head['ethnicity'] == 'Caucasian'] 
print('Caucasian: ', len(caucasian_indices))
asian_indices = [index for index, head in enumerate(data['heads']) if head['ethnicity'] == 'Asian'] 
print('Asian: ', len(asian_indices))
african_indices = [index for index, head in enumerate(data['heads']) if head['ethnicity'] == 'African'] 
print('############')

# Expression: Facial Expression
open_mouth_indices = [index for index, head in enumerate(data['heads']) if head['facial_expression'] == 'open mouth']
print('open mouth: ', len(open_mouth_indices))
smiling_indices = [index for index, head in enumerate(data['heads']) if head['facial_expression'] == 'smiling']
print('smiling: ', len(smiling_indices))
closed_eyes_indices = [index for index, head in enumerate(data['heads']) if head['facial_expression'] == 'closed eyes']
print('closed eyes: ', len(closed_eyes_indices))
raised_brows_indices = [index for index, head in enumerate(data['heads']) if head['facial_expression'] == 'raised brows']
print('raised brows: ', len(raised_brows_indices))
puffed_cheeks_indices = [index for index, head in enumerate(data['heads']) if head['facial_expression'] == 'puffed cheeks']
print('puffed cheeks: ', len(puffed_cheeks_indices))
print('############')

# Expression: Emotion 
sad_indices = [index for index, head in enumerate(data['heads']) if head['emotion'] == 'sad']
print('sad: ', len(sad_indices))
happy_indices = [index for index, head in enumerate(data['heads']) if head['emotion'] == 'happy']
print('happy: ', len(happy_indices))

# %%
print((closed_eyes_indices, raised_brows_indices, puffed_cheeks_indices))
